# %%
# Import Necessary Libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
import os

import pandas as pd
from PIL import Image
from glob import glob

from sklearn.model_selection import train_test_split
from sklearn import metrics

import cv2
import gc
import os

from tensorflow import keras
from keras import layers
import shutil
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the Pre-trained Model
model_path = '/home/mandal.n/VML/Project/cnn_model.h5'  # Update with the path to your .h5 file
cnn_model = load_model(model_path)
print("Model loaded successfully.")
# Out:
# Model loaded successfully.

# %%
path = '/home/mandal.n/VML/Project/Data/image_sets'
classes = [folder for folder in os.listdir(path) if folder != '.ipynb_checkpoints']
#classes = os.listdir(path)
classes
# Out:
# ['colon_aca', 'colon_n', 'lung_aca', 'lung_n', 'lung_scc']

# %%
path = '/home/mandal.n/VML/Project/Data/image_sets'

for cat in classes:
	image_dir = f'{path}/{cat}'
	images = os.listdir(image_dir)

	fig, ax = plt.subplots(1, 5, figsize=(15, 5))
	fig.suptitle(f'Images for {cat} category . . . .', fontsize=20)

	for i in range(5):
		k = np.random.randint(0, len(images))
		img = np.array(Image.open(f'{path}/{cat}/{images[k]}'))
		ax[i].imshow(img)
		ax[i].axis('off')
	plt.show()

# %%
def pgd_attack(model, images, labels, epsilon=0.03, alpha=0.01, num_iter=40):
    """
    Perform PGD attack with debugging to inspect intermediate pixel values.

    Parameters:
        model (tf.keras.Model): Trained model to attack.
        images (tf.Tensor): Input images.
        labels (tf.Tensor): Corresponding labels.
        epsilon (float): Maximum perturbation.
        alpha (float): Step size.
        num_iter (int): Number of attack iterations.

    Returns:
        adv_images (tf.Tensor): Adversarial images.
    """
    labels_one_hot = tf.one_hot(labels, depth=5)  # Adjust depth for your number of classes
    adv_images = tf.identity(images)  # Copy of original images

    print("Initial image pixel range:", tf.reduce_min(adv_images).numpy(), "-", tf.reduce_max(adv_images).numpy())

    for i in range(num_iter):
        with tf.GradientTape() as tape:
            tape.watch(adv_images)
            predictions = model(adv_images)
            loss = tf.keras.losses.categorical_crossentropy(labels_one_hot, predictions)

        gradients = tape.gradient(loss, adv_images)

        # Print gradient statistics
        print(f"Iteration {i+1}: Gradient range:", tf.reduce_min(gradients).numpy(), "-", tf.reduce_max(gradients).numpy())

        # Apply perturbation
        adv_images = adv_images + alpha * tf.sign(gradients)

        # Clip adversarial images
        perturbation = tf.clip_by_value(adv_images - images, -epsilon, epsilon)
        adv_images = tf.clip_by_value(images + perturbation, 0, 1)

        # Print pixel value range after clipping
        print(f"Iteration {i+1}: Adversarial image pixel range:", tf.reduce_min(adv_images).numpy(), "-", tf.reduce_max(adv_images).numpy())

    return adv_images

# %%
unwanted_dir = '/home/mandal.n/VML/Project/Data/image_sets/.ipynb_checkpoints'
if os.path.exists(unwanted_dir):
    shutil.rmtree(unwanted_dir)
dirpath='/home/mandal.n/VML/Project/Data/image_sets'
#dirpath=[folder for folder in os.listdir(path) if folder != '.ipynb_checkpoints']
IMG_SIZE=180
BATCH_SIZE=32
CHANNELS=3
EPOCHS=20
INPUT_SHAPE = (BATCH_SIZE, IMG_SIZE, IMG_SIZE, CHANNELS)
N_CLASSES = 5

# %%
dataset= tf.keras.preprocessing.image_dataset_from_directory(
    dirpath,
    seed=123,
    shuffle=True,
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 8481 files belonging to 5 classes.

# %%
# Normalize the images
#test_ds = test_ds.map(lambda x, y: (x / 255.0, tf.one_hot(y, depth=5)))

# %%
classes_name=dataset.class_names
classes_name
# Out:
# ['colon_aca', 'colon_n', 'lung_aca', 'lung_n', 'lung_scc']

# %%
for batch_img,batch_label in dataset.take(1):
    print(batch_img.shape)
    print(batch_label.numpy())
# Out:
# (32, 180, 180, 3)
# [0 4 4 1 4 3 3 2 0 4 2 2 0 0 3 1 3 4 4 3 4 4 4 0 2 1 3 2 3 2 3 4]

# %%
def split_train_val_test(dataset,train_split=0.8,test_split=0.1,val_split=0.1,shuffle=True,shuffle_size=10000):
   assert(train_split+val_split+test_split)==1


   if shuffle:
        dataset = dataset.shuffle(shuffle_size, seed=12)
    #set size of train,test and val
   train_size=int(train_split*len(dataset))
   val_size=int(val_split*len(dataset))
   test_size=int(test_split*len(dataset))


   train_ds=dataset.take(train_size)
   val_ds=dataset.skip(train_size).take(val_size)
   test_ds=dataset.skip(train_size+val_size).take(test_size)


   return train_ds,val_ds,test_ds

# %%
train,val,test=split_train_val_test(dataset)

# %%
print(len(train))
print(len(test))
print(len(val))
# Out:
# 212
# 26
# 26

# %%
train_ds = train.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.map(lambda x, y: (x / 255.0, y)) \
                 .cache() \
                 .shuffle(1000) \
                 .prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_scaling=tf.keras.Sequential([
    layers.Resizing(IMG_SIZE,IMG_SIZE),
    layers.Rescaling(1./255)
])

# %%
for images, labels in test_ds.take(1):
    print(f"Image shape: {images.shape}")
    print(f"Label shape: {labels.shape}")
    print(f"Label data type: {labels.dtype}")
# Out:
# Image shape: (32, 180, 180, 3)
# Label shape: (32,)
# Label data type: <dtype: 'int32'>

# %%
def evaluate_adversarial_examples(model, test_ds, epsilon, alpha, num_iter):
    """
    Evaluate the model on adversarial examples generated using PGD attack.

    Parameters:
        model (tf.keras.Model): Trained model.
        test_ds (tf.data.Dataset): Test dataset.
        epsilon (float): Maximum perturbation.
        alpha (float): Step size for each iteration.
        num_iter (int): Number of PGD iterations.
    """
    adv_accuracy = 0
    total_samples = 0
    for images, labels in test_ds:
        # Generate adversarial examples
        adv_images = pgd_attack(model, images, labels, epsilon=epsilon, alpha=alpha, num_iter=num_iter)
        
        # Get predictions for adversarial examples
        predictions = model.predict(adv_images)
        predicted_classes = np.argmax(predictions, axis=1)  # Predicted class indices
        
        # Compare predicted classes with true class labels
        adv_accuracy += np.sum(predicted_classes == labels.numpy())  # Direct comparison
        total_samples += labels.shape[0]
    
    adv_accuracy /= total_samples
    print(f"Accuracy on adversarial examples: {adv_accuracy * 100:.2f}%")

# %%
def visualize_adversarial_examples(model, test_ds, epsilon=0.03, alpha=0.01, num_iter=5, num_samples=5):
    """
    Visualize original and adversarial examples with debugging.

    Parameters:
        model (tf.keras.Model): Trained model.
        test_ds (tf.data.Dataset): Test dataset.
        epsilon (float): Maximum perturbation.
        alpha (float): Step size for each iteration.
        num_iter (int): Number of PGD iterations.
        num_samples (int): Number of images to visualize.
    """
    for images, labels in test_ds.take(1):  # Take one batch
        adv_images = pgd_attack(model, images, labels, epsilon=epsilon, alpha=alpha, num_iter=num_iter)

        # Print pixel range before visualization
        print("Original image pixel range:", tf.reduce_min(images).numpy(), "-", tf.reduce_max(images).numpy())
        print("Adversarial image pixel range:", tf.reduce_min(adv_images).numpy(), "-", tf.reduce_max(adv_images).numpy())

        plt.figure(figsize=(10, 5))
        for i in range(num_samples):
            # Original Image
            plt.subplot(2, num_samples, i + 1)
            plt.imshow((images[i].numpy() * 255).astype("uint8"))  # Scale to [0, 255] if needed
            plt.title("Original")
            plt.axis("off")

            # Adversarial Image
            plt.subplot(2, num_samples, i + 1 + num_samples)
            plt.imshow((adv_images[i].numpy() * 255).astype("uint8"))  # Scale to [0, 255] if needed
            plt.title("Adversarial")
            plt.axis("off")

        plt.tight_layout()
        plt.show()

# %%
# Evaluate and Visualize
evaluate_adversarial_examples(cnn_model, test_ds, epsilon=0.03, alpha=0.01, num_iter=5)
visualize_adversarial_examples(cnn_model, test_ds, epsilon=0.03, alpha=0.01, num_iter=5)
# Out:
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0017267775 - 0.00140324
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0015677044 - 0.0014262887
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0019948499 - 0.0011692094
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0013388562 - 0.0013233583
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0016731268 - 0.0012720582
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 441ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0014705927 - 0.0012233382
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0013221009 - 0.0012375755
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0011025692 - 0.0011729969
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0010424912 - 0.001168475
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0011452942 - 0.0012002181
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 33ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0016454285 - 0.0015052131
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0014569792 - 0.0015429861
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0015446132 - 0.0012343642
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0015085369 - 0.0013101978
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.00154826 - 0.0012095175
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 36ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0015251529 - 0.0013585653
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0014125655 - 0.0012113285
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0014238828 - 0.0010859001
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0013432709 - 0.0012106455
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0015212346 - 0.0009958299
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 36ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0014776854 - 0.0012369406
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0015545783 - 0.0011327171
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0013966274 - 0.0011549231
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0013615544 - 0.0014355972
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0014677198 - 0.0011878683
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 37ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0015353413 - 0.0014324439
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0014745827 - 0.0013048699
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0016267153 - 0.0013372753
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0013968345 - 0.0012410283
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.001674229 - 0.0014223759
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 30ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0018544504 - 0.0015752723
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0021133395 - 0.0015102964
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0022900298 - 0.0014444493
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.002085796 - 0.0014188791
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0020012828 - 0.001495414
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 30ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0017974444 - 0.0015699761
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0014962902 - 0.0013535438
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0016145585 - 0.0013060542
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0012696603 - 0.0011986013
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0016770888 - 0.0013577044
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 32ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0017359874 - 0.0016435048
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0013463601 - 0.0015898825
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0013782217 - 0.0014316005
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0014803265 - 0.0012219482
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0014030798 - 0.001479348
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 32ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0012845296 - 0.0015461209
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0013269617 - 0.0014492907
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0013264555 - 0.0013791554
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0012280041 - 0.0010332653
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0013174907 - 0.0010897772
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 31ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0014686808 - 0.0014665643
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0014059311 - 0.0015539182
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0015104582 - 0.00151578
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0013774686 - 0.0015933132
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0014426857 - 0.0014274056
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 31ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.001607466 - 0.0016824832
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0013104362 - 0.0014648157
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.001296295 - 0.0014548447
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0014651238 - 0.0016670171
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0014549862 - 0.0014921187
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 32ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0015695316 - 0.0013601681
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0015636531 - 0.0012103779
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0016551793 - 0.0013271304
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.001711862 - 0.0013742655
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0015400881 - 0.0013809392
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 32ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0015145605 - 0.0014902315
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0014389182 - 0.0011209289
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0014763967 - 0.0012006065
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0015499223 - 0.0011316523
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.001644354 - 0.0012338009
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 30ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.001866146 - 0.0013682178
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0015767099 - 0.0013692116
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0017949397 - 0.0012414124
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0014876149 - 0.001247677
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0020541148 - 0.0011692535
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 31ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0014573843 - 0.0013054267
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0017865617 - 0.0013726312
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.001744371 - 0.0012931172
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0018090124 - 0.001339692
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0016576424 - 0.0011575232
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 32ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0015772448 - 0.0015117528
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.001598299 - 0.0015579468
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0018093251 - 0.0012836086
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0014335552 - 0.0011818317
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0017863386 - 0.001272212
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 32ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0019809145 - 0.0019836293
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0015195113 - 0.0019386429
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0017490472 - 0.0016394721
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0014886422 - 0.0012282863
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0017139359 - 0.0013211605
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 38ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0015335055 - 0.0013900622
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0014999137 - 0.0016430687
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0015821189 - 0.0012920706
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0014974548 - 0.0012930541
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0014590576 - 0.0013091543
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 31ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.001767555 - 0.0013663803
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0014725878 - 0.0015364963
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.001319262 - 0.0015135409
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0015570384 - 0.0014358021
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.001585388 - 0.0016043837
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 29ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0017927694 - 0.0017099974
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0020529074 - 0.0015281296
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0018117628 - 0.0015155146
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0019138906 - 0.0017060969
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0019866796 - 0.0014489134
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 30ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0020954963 - 0.0020843665
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.002172919 - 0.0020152535
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.002011004 - 0.001340899
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0018828945 - 0.0017228218
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0022393505 - 0.0016227989
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 32ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0015435118 - 0.0014264642
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0013696338 - 0.0012905782
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0015227838 - 0.0012993109
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.001344749 - 0.001335642
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.00150022 - 0.001196082
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 38ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0014243893 - 0.0012426402
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0017549599 - 0.0011961021
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0015480611 - 0.0011622175
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0015200286 - 0.0010426784
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0016961701 - 0.0012992003
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 32ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.001512144 - 0.0012727295
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0015866725 - 0.0013917249
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0016265614 - 0.0011911457
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.00154964 - 0.0010698421
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0017444608 - 0.0012433887
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 29ms/step
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0014728422 - 0.0013429851
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0014379176 - 0.0015860428
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0018157264 - 0.0015217778
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0013847238 - 0.0012373368
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0016855206 - 0.0014197477
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# 1/1 [==============================] - 0s 32ms/step
# Accuracy on adversarial examples: 18.27%
# Initial image pixel range: 0.0 - 1.0
# Iteration 1: Gradient range: -0.0019809147 - 0.0019836293
# Iteration 1: Adversarial image pixel range: 0.0 - 1.0
# Iteration 2: Gradient range: -0.0015195112 - 0.0019386429
# Iteration 2: Adversarial image pixel range: 0.0 - 1.0
# Iteration 3: Gradient range: -0.0017490472 - 0.0016394719
# Iteration 3: Adversarial image pixel range: 0.0 - 1.0
# Iteration 4: Gradient range: -0.0014886422 - 0.0012282863
# Iteration 4: Adversarial image pixel range: 0.0 - 1.0
# Iteration 5: Gradient range: -0.0017139359 - 0.0013211605
# Iteration 5: Adversarial image pixel range: 0.0 - 1.0
# Original image pixel range: 0.0 - 1.0
# Adversarial image pixel range: 0.0 - 1.0
